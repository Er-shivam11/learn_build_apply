# %% [markdown]
# # 🟢 LEETCODE / DSA PRIORITY ROADMAP
#
# ## 1️⃣ ARRAY — 🔥 HIGHEST PRIORITY
#
# - [x] Two Sum
# - [x] Best Time to Buy and Sell Stock
# - [x] Contains Duplicate
# - [ ] Product of Array Except Self
# - [x] Maximum Subarray
# - [ ] Maximum Product Subarray
# - [ ] Find Minimum in Rotated Sorted Array
# - [ ] Search in Rotated Sorted Array
# - [ ] 3Sum
# - [ ] Container With Most Water
#
#
# ## 2️⃣ STRING — 🔥 HIGHEST PRIORITY
#
# - [ ] Valid Anagram
# - [ ] Valid Palindrome
# - [ ] Longest Substring Without Repeating Characters
# - [ ] Group Anagrams
# - [ ] Valid Parentheses
# - [ ] Longest Repeating Character Replacement
# - [ ] Minimum Window Substring
# - [ ] Longest Palindromic Substring
# - [ ] Palindromic Substrings
# - [ ] Encode and Decode Strings
#
#
# ## 3️⃣ HASHING / FREQUENCY — 🔥 CORE PATTERN
#
# Mostly covered through Array + String, but reinforce:
#
# - [x] Contains Duplicate → HashSet
# - [x] Two Sum → HashMap
# - [ ] Group Anagrams → HashMap
# - [ ] Top K Frequent Elements → HashMap + Heap
# - [ ] Longest Consecutive Sequence → HashSet
#
#
# ## 4️⃣ TWO POINTERS / SLIDING WINDOW — 🔥 VERY IMPORTANT
#
# - [ ] 3Sum
# - [ ] Container With Most Water
# - [ ] Valid Palindrome
# - [ ] Longest Substring Without Repeating Characters
# - [ ] Longest Repeating Character Replacement
# - [ ] Minimum Window Substring
#
#
# ## 5️⃣ LINKED LIST — 🔥 HIGH PRIORITY
#
# - [ ] Reverse a Linked List
# - [ ] Detect Cycle in a Linked List
# - [ ] Merge Two Sorted Lists
# - [ ] Remove Nth Node From End Of List
# - [ ] Reorder List
# - [ ] Merge K Sorted Lists
#
#
# ## 6️⃣ BINARY SEARCH — 🔥 HIGH PRIORITY
#
# - [ ] Find Minimum in Rotated Sorted Array
# - [ ] Search in Rotated Sorted Array
#
#
# ## 7️⃣ TREE — 🔥 HIGH PRIORITY
#
# - [ ] Maximum Depth of Binary Tree
# - [ ] Same Tree
# - [ ] Invert/Flip Binary Tree
# - [ ] Binary Tree Level Order Traversal
# - [ ] Validate Binary Search Tree
# - [ ] Kth Smallest Element in a BST
# - [ ] Lowest Common Ancestor of BST
# - [ ] Subtree of Another Tree
# - [ ] Binary Tree Maximum Path Sum
# - [ ] Serialize and Deserialize Binary Tree
# - [ ] Construct Binary Tree from Preorder and Inorder Traversal
#
#
# ## 8️⃣ STACK / INTERVAL — HIGH PRIORITY
#
# ### Stack
#
# - [ ] Valid Parentheses
#
# ### Interval
#
# - [ ] Merge Intervals
# - [ ] Insert Interval
# - [ ] Non-overlapping Intervals
# - [ ] Meeting Rooms
# - [ ] Meeting Rooms II
#
#
# ## 9️⃣ HEAP — MEDIUM/HIGH PRIORITY
#
# - [ ] Top K Frequent Elements
# - [ ] Merge K Sorted Lists
# - [ ] Find Median from Data Stream
#
#
# ## 🔟 GRAPH — HIGH PRIORITY BUT AFTER CORE PATTERNS
#
# - [ ] Number of Islands
# - [ ] Clone Graph
# - [ ] Course Schedule
# - [ ] Pacific Atlantic Water Flow
# - [ ] Longest Consecutive Sequence
# - [ ] Graph Valid Tree
# - [ ] Number of Connected Components
# - [ ] Alien Dictionary
#
#
# ## 1️⃣1️⃣ DYNAMIC PROGRAMMING — IMPORTANT, BUT LATER
#
# - [ ] Climbing Stairs
# - [ ] House Robber
# - [ ] House Robber II
# - [ ] Jump Game
# - [ ] Unique Paths
# - [ ] Coin Change
# - [ ] Decode Ways
# - [ ] Word Break
# - [ ] Combination Sum IV
# - [ ] Longest Increasing Subsequence
# - [ ] Longest Common Subsequence
#
#
# ## 1️⃣2️⃣ MATRIX
#
# - [ ] Set Matrix Zeroes
# - [ ] Spiral Matrix
# - [ ] Rotate Image
# - [ ] Word Search
#
#
# ## 1️⃣3️⃣ BINARY / BIT MANIPULATION
#
# - [ ] Number of 1 Bits
# - [ ] Missing Number
# - [ ] Counting Bits
# - [ ] Reverse Bits
# - [ ] Sum of Two Integers
#
#
# # 📊 CURRENT STATUS
#
# Array:
# ✅ 4 / 10
#
# String:
# ⬜ 0 / 10
#
# Overall:
# ✅ 4 problems solved
#
# NEXT:
# → Finish remaining important Array patterns
# → Then move heavily into String + Hashing + Sliding Window
